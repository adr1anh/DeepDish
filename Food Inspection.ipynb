# %%
import pandas as pd

# %%
data = pd.read_csv('chicago-food-inspections/food-inspections.csv')

# %%
data.head()
# Out:
#    Inspection ID                  DBA Name                  AKA Name  \
# 0        2320315     SERENDIPITY CHILDCARE     SERENDIPITY CHILDCARE
# 1        2320342         YOLK TEST KITCHEN         YOLK TEST KITCHEN
# 2        2320328  LAS ASADAS MEXICAN GRILL  LAS ASADAS MEXICAN GRILL
# 3        2320319               LA PALAPITA               LA PALAPITA
# 4        2320228           47TH ST CANTINA           47TH ST CANTINA
#
#    License #                    Facility Type           Risk  \
# 0  2216009.0  Daycare Above and Under 2 Years  Risk 1 (High)
# 1  2589655.0                       Restaurant  Risk 1 (High)
# 2  2583309.0                       Restaurant  Risk 1 (High)
# 3  2694702.0                       Restaurant  Risk 1 (High)
# 4  2678250.0                           Liquor   Risk 3 (Low)
#
#                  Address     City State      Zip  ...             Results  \
# 0        1300 W 99TH ST   CHICAGO    IL  60643.0  ...                Pass
# ...

# %%
print(data['Facility Type'].value_counts())
# Out:
# Restaurant                                  129847
# Grocery Store                                24846
# School                                       12076
# Children's Services Facility                  3018
# Bakery                                        2856
#                                              ...
# FROZEN DESSERTS DISPENSER -NON MOTORIZED         1
# FOOD PANTRY                                      1
# religious                                        1
# TAVERN/LIQUOR                                    1
# GAS STATION/GROCERY                              1
# Name: Facility Type, Length: 488, dtype: int64

# %%
data.describe()
# Out:
#        Inspection ID     License #            Zip       Latitude  \
# count   1.948140e+05  1.947970e+05  194764.000000  194133.000000
# mean    1.440338e+06  1.596390e+06   60628.734925      41.881282
# std     6.324852e+05  8.957803e+05     122.536605       0.080815
# min     4.424700e+04  0.000000e+00   10014.000000      41.644670
# 25%     1.150290e+06  1.223250e+06   60614.000000      41.835213
# 50%     1.490294e+06  1.975752e+06   60625.000000      41.891943
# 75%     1.989746e+06  2.232948e+06   60643.000000      41.939827
# max     2.320342e+06  9.999999e+06   60827.000000      42.021064
#
#            Longitude  Historical Wards 2003-2015  Zip Codes  Community Areas  \
# count  194133.000000                         0.0        0.0              0.0
# mean      -87.676873                         NaN        NaN              NaN
# std         0.058931                         NaN        NaN              NaN
# ...
